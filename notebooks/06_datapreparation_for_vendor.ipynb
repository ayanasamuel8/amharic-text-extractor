# %%
import pandas as pd
from pathlib import Path

# Load our reusable cleaning functions
import sys
sys.path.append('../scripts')  # Add path to access preprocess.py

from preprocess import clean_text

# %%
from preprocess import preprocess_dataframe

# %%
csv_path = Path('../data/raw/rawtelegram_data.csv')
df = pd.read_csv(csv_path)

print(f"Total messages loaded: {len(df)}")
df.head()
# Out:
# Total messages loaded: 6300
#     Channel Title Channel Username  Message ID  \
# 0  Zemen Express®    @ZemenExpress        7007
# 1  Zemen Express®    @ZemenExpress        7006
# 2  Zemen Express®    @ZemenExpress        7005
# 3  Zemen Express®    @ZemenExpress        7004
# 4  Zemen Express®    @ZemenExpress        7003
#
#                                         Message Text  \
# 0  💥💥...................................💥💥\n\n🎯 L...
# 1  💥💥...................................💥💥\n\n🎯 L...
# 2  💥💥...................................💥💥\n\n🎯 L...
# 3  💥💥👀 ...........💥💥\n\n📌 Electric Charcoal Burne...
# 4                                                NaN
#
#                         Date  Views  Replies  Forwards
# 0  2025-06-24 11:49:18+00:00   1187        0         1
# 1  2025-06-24 11:49:01+00:00    973        0         2
# 2  2025-06-24 11:48:41+00:00   1004        0         0
# 3  2025-06-23 14:55:46+00:00   2255        0         3
# 4  2025-06-23 14:55:40+00:00   1925        0         0

# %%
df_processed = preprocess_dataframe(df, text_col='Message Text')

print(f"Total messages after cleaning: {len(df_processed)}")
df_processed.head(3)
# Out:
# Total messages after cleaning: 4490
#     Channel Title Channel Username  Message ID  \
# 0  Zemen Express®    @ZemenExpress        7007
# 1  Zemen Express®    @ZemenExpress        7006
# 2  Zemen Express®    @ZemenExpress        7005
#
#                                         Message Text  \
# 0  💥💥...................................💥💥\n\n🎯 L...
# 1  💥💥...................................💥💥\n\n🎯 L...
# 2  💥💥...................................💥💥\n\n🎯 L...
#
#                         Date  Views  Replies  Forwards  \
# 0  2025-06-24 11:49:18+00:00   1187        0         1
# 1  2025-06-24 11:49:01+00:00    973        0         2
# 2  2025-06-24 11:48:41+00:00   1004        0         0
#
#                                         cleaned_text  \
# 0  ................................... ልጅዎ 8.5 ልጆ...
# 1  ................................... ልጅዎ 8.5 ልጆ...
# 2  ................................... ልጅዎ 8.5 ልጆ...
#
#                                               tokens
# 0  [▁..., ................, ................, ▁ልጅ...
# 1  [▁..., ................, ................, ▁ልጅ...
# 2  [▁..., ................, ................, ▁ልጅ...

# %%
for i, row in df_processed.sample(5).iterrows():
    print(f"Original Message:\n{row['Message Text']}\n")
    print(f"Cleaned Text:\n{row['cleaned_text']}\n")
    print(f"Tokens:\n{row['tokens']}\n")
    print("-"*60)
# Out:
# Original Message:
# 💥💥...................................💥💥
#
# 📌 Multifunctional Electric baking Pan
#
# ➡️በኤሌትሪክ የሚሰራ ምጣድ
#
# 👍ለአሳንቡሳ ፣ ለቂጣ፣ ለመለዋ፣ ለፈጢራ የሚሆን
# 👍በአነስተኛ የኤሌትሪክ ሀይል የሚሰራ
# 👍ሶኬቱ ላይ የሀይል መቆጣጠሪያ ፊዉዝ የተገጠመለት
#
# 👍Specifications
# 👍#Size: 38 cm & 34 cm
# 👍Rated voltage: 220V
# 👍Rated Frequency: 50Hz
# 👍Rated Power: 200W
#
# ዋጋ፦  💲🏷  38cm ➡️ 3200 ብር
#                      34cm  ➡️ 2800 ብር
#
# 🏢 አድራሻ👉
#
# 📍ቁ.1️⃣♦️መገናኛ መሰረት ደፋር ሞል ሁለተኛ ፎቅ ቢሮ ቁ. S05 👣
#
# 📍 ቁ.2️⃣♦️ፒያሳ ጊዮርጊስ አደባባይ ራመት_ታቦር_ኦዳ_ህንፃ 1ኛ ፎቅ ሱቅ ቁ. G1 -07 👣
#
#      💧💧💧💧
#
#
#     📲 0902660722
#     📲 0928460606
#
# 🔖
# 💬በTelegram ለማዘዝ ⤵️ ይጠቀሙ🔽
#
# @zemencallcenter
#
# @zemenexpressadmin
#
# ለተጨማሪ ማብራሪያ የቴሌግራም ገፃችን⤵️
# https://telegram.me/zemenexpress
#
# 💥💥...................................💥💥
#
# Cleaned Text:
# ................................... ኤሌትሪክ ሚሰራ ምጣድ አሳንቡሳ . ቂጣ. መለዋ. ፈጢራ ሚሆን አነስተኛ ኤሌትሪክ ሀይል ሚሰራ ሶኬቱ ላይ ሀይል መቆጣጠሪያ ፊዉዝ ተገጠመለት 38 34 220 50 200 ዋጋ፦ 38 3200 ብር 34 2800 ብር አድራሻ ቁ.1መገናኛ መሰረት ደፋር ሞል ሁለተኛ ፎቅ ቢሮ ቁ. 05 ቁ.2ፒያሳ ጊዮርጊስ አደባባይ ራመትታቦርኦዳህንፃ 1ኛ ፎቅ ሱቅ ቁ. 1 07 0902660722 0928460606 በ ማዘዝ ይጠቀሙ ተጨማሪ ማብራሪያ ቴሌግራም ገፃችን ...................................
#
# Tokens:
# ['▁...', '................', '................', '▁ኤ', 'ሌት', 'ሪክ', '▁ሚ', 'ሰራ', '▁ም', 'ጣ', 'ድ', '▁አሳ', 'ን', 'ቡ', 'ሳ', '▁', '.', '▁', 'ቂ', 'ጣ', '.', '▁መ', 'ለዋ', '.', '▁ፈ', 'ጢ', 'ራ', '▁ሚ', 'ሆን', '▁አነስተኛ', '▁ኤ', 'ሌት', 'ሪክ', '▁ሀ', 'ይል', '▁ሚ', 'ሰራ', '▁', 'ሶ', 'ኬ', 'ቱ', '▁ላይ', '▁ሀ', 'ይል', '▁መቆ', 'ጣ', 'ጠ', 'ሪያ', '▁', 'ፊ', 'ዉ', 'ዝ', '▁ተገ', 'ጠ', 'መ', 'ለት', '▁38', '▁34', '▁220', '▁50', '▁200', '▁ዋጋ', '፦', '▁38', '▁3', '200', '▁ብር', '▁34', '▁2', '800', '▁ብር', '▁አድራሻ', '▁ቁ', '.', '1', 'መ', 'ገና', 'ኛ', '▁መሰረት', '▁ደ', 'ፋር', '▁ሞ', 'ል', '▁', 'ሁለተኛ', '▁', 'ፎ', 'ቅ', '▁ቢሮ', '▁ቁ', '.', '▁05', '▁ቁ', '.', '2', 'ፒ', 'ያ', 'ሳ', '▁', 'ጊዮርጊስ', '▁አደባባይ', '▁', 'ራ', 'መት', 'ታ', 'ቦ', 'ር', 'ኦ', 'ዳ', 'ህን', 'ፃ', '▁1', 'ኛ', '▁', 'ፎ', 'ቅ', '▁', 'ሱ', 'ቅ', '▁ቁ', '.', '▁1', '▁07', '▁09', '02', '660', '722', '▁09', '28', '460', '606', '▁በ', '▁ማ', 'ዘ', 'ዝ', '▁ይ', 'ጠቀሙ', '▁ተጨማሪ', '▁ማብራሪያ', '▁', 'ቴ', 'ሌ', 'ግራ', 'ም', '▁ገ', 'ፃ', 'ችን', '▁...', '................', '................']
#
# ------------------------------------------------------------
# Original Message:
# 🎯 የእንቁላል መምቻ እና የኬክ ቅርፅ ማውጫ
#
# ዋጋ፦  💰🏷  1350 ብር
#
# ♦️ውስን ፍሬ ነው ያለው
#
# 🏢 አድራሻ👉 መገናኛ ደራርቱ ህንፃ ጎን መሰረት ደፋር ሞል ሁለተኛ ፎቅ ቢሮ ቁ. S05/S06
#
#      💧💧💧💧
#
#
#     📲 0902660722
#     📲 0928460606
#
# 🔖
# 💬  በTelegram ለማዘዝ ⤵️ ይጠቀሙ
# @zemencallcenter
#  @zemenexpressadmin
#
# ለተጨማሪ ማብራሪያ የቴሌግራም ገፃችን⤵️
# https://telegram.me/zemenexpress
#
# Cleaned Text:
# እንቁላል መምቻ እና ኬክ ቅርፅ ማውጫ ዋጋ፦ 1350 ብር ውስን ፍሬ ነው ያለው አድራሻ መገናኛ ደራርቱ ህንፃ ጎን መሰረት ደፋር ሞል ሁለተኛ ፎቅ ቢሮ ቁ. 0506 0902660722 0928460606 በ ማዘዝ ይጠቀሙ ተጨማሪ ማብራሪያ ቴሌግራም ገፃችን
#
# Tokens:
# ['▁እን', 'ቁ', 'ላል', '▁', 'መም', 'ቻ', '▁እና', '▁', 'ኬ', 'ክ', '▁ቅር', 'ፅ', '▁', 'ማው', 'ጫ', '▁ዋጋ', '፦', '▁13', '50', '▁ብር', '▁', 'ውስ', 'ን', '▁ፍ', 'ሬ', '▁ነው', '▁ያለው', '▁አድራሻ', '▁መ', 'ገና', 'ኛ', '▁', 'ደራ', 'ር', 'ቱ', '▁', 'ህን', 'ፃ', '▁ጎ', 'ን', '▁መሰረት', '▁ደ', 'ፋር', '▁ሞ', 'ል', '▁', 'ሁለተኛ', '▁', 'ፎ', 'ቅ', '▁ቢሮ', '▁ቁ', '.', '▁05', '06', '▁09', '02', '660', '722', '▁09', '28', '460', '606', '▁በ', '▁ማ', 'ዘ', 'ዝ', '▁ይ', 'ጠቀሙ', '▁ተጨማሪ', '▁ማብራሪያ', '▁', 'ቴ', 'ሌ', 'ግራ', 'ም', '▁ገ', 'ፃ', 'ችን']
#
# ------------------------------------------------------------
# Original Message:
# 🎯 Kumtel Oven
#
# 🔰32ሊትር
# 🔰ባለ 2 ፓትራ
#
# ዋጋ፦  💰🏷  2600ብር
#
#
# 🏢 አድራሻ👉 መገናኛ ደራርቱ ህንፃ ጎን መሰረት ደፋር ሞል ሁለተኛ ፎቅ ቢሮ ቁ. S05/S06
#
# 📌🚚 ያሉበት ድረስ በነፃ እናደርሳለን 🚚
#      💧💧💧💧
#
#
#     📲 0902660722
#     📲 0928460606
#
# 🔖
# 💬  በTelegram ለማዘዝ ⤵️ ይጠቀሙ
# @zemencallcenter
#  @zemenexpressadmin
#
# ለተጨማሪ ማብራሪያ የቴሌግራም ገፃችን⤵️
# https://telegram.me/zemenexpress
#
# Cleaned Text:
# 32ሊትር ባለ 2 ፓትራ ዋጋ፦ 2600ብር አድራሻ መገናኛ ደራርቱ ህንፃ ጎን መሰረት ደፋር ሞል ሁለተኛ ፎቅ ቢሮ ቁ. 0506 ያሉበት ድረስ ነፃ እናደርሳለን 0902660722 0928460606 በ ማዘዝ ይጠቀሙ ተጨማሪ ማብራሪያ ቴሌግራም ገፃችን
#
# Tokens:
# ['▁32', 'ሊ', 'ትር', '▁ባለ', '▁2', '▁ፓ', 'ት', 'ራ', '▁ዋጋ', '፦', '▁2600', 'ብር', '▁አድራሻ', '▁መ', 'ገና', 'ኛ', '▁', 'ደራ', 'ር', 'ቱ', '▁', 'ህን', 'ፃ', '▁ጎ', 'ን', '▁መሰረት', '▁ደ', 'ፋር', '▁ሞ', 'ል', '▁', 'ሁለተኛ', '▁', 'ፎ', 'ቅ', '▁ቢሮ', '▁ቁ', '.', '▁05', '06', '▁ያሉ', 'በት', '▁ድረስ', '▁ነፃ', '▁እና', 'ደር', 'ሳ', 'ለን', '▁09', '02', '660', '722', '▁09', '28', '460', '606', '▁በ', '▁ማ', 'ዘ', 'ዝ', '▁ይ', 'ጠቀሙ', '▁ተጨማሪ', '▁ማብራሪያ', '▁', 'ቴ', 'ሌ', 'ግራ', 'ም', '▁ገ', 'ፃ', 'ችን']
#
# ------------------------------------------------------------
# Original Message:
# 🎯Vaccuum flask set
#
# 🔰የፔርሙዝ ማግ
# 🔰3 መጠጫ ኩባያዎች ያሉት
# 🔰ለ 12 ሰአታት የሞቀዉን አሙቆ የቀዘቀዘዉን አቀዝቅዞ ሚያስቀምጥ
# 🔰ድንገት ቢወድቅ እንኳን ከማይሰበር ማቴሪያል የተሰራ
# 🔰500ሚሊ ሊትር የመያዝ አቅም ያለዉ
# 🔰በተለያየ የከለር አማራጭ የቀረበ
# 🔰ለስጦታ የሚሆን የራሱ ማሸጊያና መያዣ ያለዉ
#
# ዋጋ፦  💰🏷  1300 ብር
#
# 📍ውስን ፍሬ ነው ያለን/ Limited Stock
#
# 🏢 አድራሻ👉 መገናኛ ደራርቱ ህንፃ ጎን መሰረት ደፋር ሞል ሁለተኛ ፎቅ ቢሮ ቁ. S05/S06
#
#      💧💧💧💧
#
#
#     📲 0902660722
#     📲 0928460606
#
# 🔖
# 💬  በTelegram ለማዘዝ ⤵️ ይጠቀሙ
# @zemencallcenter
# @zemenexpressadmin
#
# ለተጨማሪ ማብራሪያ የቴሌግራም ገፃችን⤵️
# https://telegram.me/zemenexpress
#
# Cleaned Text:
# ፔርሙዝ ማግ 3 መጠጫ ኩባያዎች ያሉት ለ 12 ሰአታት ሞቀዉን አሙቆ ቀዘቀዘዉን አቀዝቅዞ ሚያስቀምጥ ድንገት ቢወድቅ እንኳን ማይሰበር ማቴሪያል ተሰራ 500ሚሊ ሊትር መያዝ አቅም ያለዉ ተለያየ ከለር አማራጭ ቀረበ ስጦታ ሚሆን ራሱ ማሸጊያና መያዣ ያለዉ ዋጋ፦ 1300 ብር ውስን ፍሬ ነው ያለን አድራሻ መገናኛ ደራርቱ ህንፃ ጎን መሰረት ደፋር ሞል ሁለተኛ ፎቅ ቢሮ ቁ. 0506 0902660722 0928460606 በ ማዘዝ ይጠቀሙ ተጨማሪ ማብራሪያ ቴሌግራም ገፃችን
#
# Tokens:
# ['▁', 'ፔ', 'ር', 'ሙ', 'ዝ', '▁ማ', 'ግ', '▁3', '▁መጠ', 'ጫ', '▁', 'ኩ', 'ባ', 'ያ', 'ዎች', '▁ያሉት', '▁ለ', '▁12', '▁ሰ', 'አ', 'ታት', '▁ሞ', 'ቀ', 'ዉን', '▁አ', 'ሙ', 'ቆ', '▁ቀ', 'ዘ', 'ቀ', 'ዘ', 'ዉን', '▁', 'አቀ', 'ዝ', 'ቅ', 'ዞ', '▁ሚ', 'ያስ', 'ቀም', 'ጥ', '▁', 'ድን', 'ገት', '▁ቢ', 'ወድ', 'ቅ', '▁እንኳን', '▁', 'ማይ', 'ሰበ', 'ር', '▁ማ', 'ቴ', 'ሪያ', 'ል', '▁ተ', 'ሰራ', '▁500', 'ሚ', 'ሊ', '▁ሊ', 'ትር', '▁መ', 'ያዝ', '▁አቅም', '▁ያለ', 'ዉ', '▁', 'ተለያየ', '▁ከ', 'ለ', 'ር', '▁አማራጭ', '▁', 'ቀረበ', '▁ስጦታ', '▁ሚ', 'ሆን', '▁', 'ራሱ', '▁ማ', 'ሸ', 'ጊያ', 'ና', '▁መ', 'ያ', 'ዣ', '▁ያለ', 'ዉ', '▁ዋጋ', '፦', '▁1300', '▁ብር', '▁', 'ውስ', 'ን', '▁ፍ', 'ሬ', '▁ነው', '▁ያለ', 'ን', '▁አድራሻ', '▁መ', 'ገና', 'ኛ', '▁', 'ደራ', 'ር', 'ቱ', '▁', 'ህን', 'ፃ', '▁ጎ', 'ን', '▁መሰረት', '▁ደ', 'ፋር', '▁ሞ', 'ል', '▁', 'ሁለተኛ', '▁', 'ፎ', 'ቅ', '▁ቢሮ', '▁ቁ', '.', '▁05', '06', '▁09', '02', '660', '722', '▁09', '28', '460', '606', '▁በ', '▁ማ', 'ዘ', 'ዝ', '▁ይ', 'ጠቀሙ', '▁ተጨማሪ', '▁ማብራሪያ', '▁', 'ቴ', 'ሌ', 'ግራ', 'ም', '▁ገ', 'ፃ', 'ችን']
#
# ------------------------------------------------------------
# Original Message:
#  🎯Sonic Facial Cleansing Brush Skin Spa Care Waterproof Electric Face Scrub.
#
# 🔰Suitable for:
#      ⚜Cleansing the skin,
#      ⚜ removing makeup, oil, and     dirt on face.
# 🔰4 x Brush Head.
# 🔰1 Cleanse the skin 10x better than hand washing.
#
# ዋጋ፦  💰🏷  550 ብር
#
# 🏢 አድራሻ👉 መገናኛ ደራርቱ ህንፃ ጎን መሰረት ደፋር ሞል ሁለተኛ ፎቅ ቢሮ ቁ. S05/S06
#      💧💧💧💧
#
#
#     📲 0902660722
#     📲 0928460606
#
# 🔖
# 💬  በTelegram ለማዘዝ ⤵️ ይጠቀሙ
# @zemencallcenter
#  @zemenexpressadmin
#
# ለተጨማሪ ማብራሪያ የቴሌግራም ገፃችን⤵️
# https://telegram.me/zemenexpress
#
# Cleaned Text:
# . , , , . 4 . 1 10 . ዋጋ፦ 550 ብር አድራሻ መገናኛ ደራርቱ ህንፃ ጎን መሰረት ደፋር ሞል ሁለተኛ ፎቅ ቢሮ ቁ. 0506 0902660722 0928460606 በ ማዘዝ ይጠቀሙ ተጨማሪ ማብራሪያ ቴሌግራም ገፃችን
#
# Tokens:
# ['▁', '.', '▁', ',', '▁', ',', '▁', ',', '▁', '.', '▁4', '▁', '.', '▁1', '▁10', '▁', '.', '▁ዋጋ', '፦', '▁550', '▁ብር', '▁አድራሻ', '▁መ', 'ገና', 'ኛ', '▁', 'ደራ', 'ር', 'ቱ', '▁', 'ህን', 'ፃ', '▁ጎ', 'ን', '▁መሰረት', '▁ደ', 'ፋር', '▁ሞ', 'ል', '▁', 'ሁለተኛ', '▁', 'ፎ', 'ቅ', '▁ቢሮ', '▁ቁ', '.', '▁05', '06', '▁09', '02', '660', '722', '▁09', '28', '460', '606', '▁በ', '▁ማ', 'ዘ', 'ዝ', '▁ይ', 'ጠቀሙ', '▁ተጨማሪ', '▁ማብራሪያ', '▁', 'ቴ', 'ሌ', 'ግራ', 'ም', '▁ገ', 'ፃ', 'ችን']
#
# ------------------------------------------------------------

# %%
output_path = Path('../data/processed/cleaned_messages.csv')
output_path.parent.mkdir(parents=True, exist_ok=True)

df_processed.to_csv(output_path, index=False, encoding='utf-8-sig')
print(f"[✅] Saved cleaned and tokenized data to {output_path}")
# Out:
# [✅] Saved cleaned and tokenized data to ..\data\processed\cleaned_messages.csv
