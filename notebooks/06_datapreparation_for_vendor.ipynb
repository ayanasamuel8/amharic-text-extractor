# %%
import pandas as pd
from pathlib import Path

# Load our reusable cleaning functions
import sys
sys.path.append('../scripts')  # Add path to access preprocess.py

from preprocess import clean_text

# %%
from preprocess import preprocess_dataframe

# %%
csv_path = Path('../data/raw/rawtelegram_data.csv')
df = pd.read_csv(csv_path)

print(f"Total messages loaded: {len(df)}")
df.head(10)
# Out:
# Total messages loaded: 26713
#     Channel Title Channel Username  Message ID  \
# 0  Zemen Express®    @ZemenExpress        7007
# 1  Zemen Express®    @ZemenExpress        7006
# 2  Zemen Express®    @ZemenExpress        7005
# 3  Zemen Express®    @ZemenExpress        7004
# 4  Zemen Express®    @ZemenExpress        7003
# 5  Zemen Express®    @ZemenExpress        7002
# 6  Zemen Express®    @ZemenExpress        7001
# 7  Zemen Express®    @ZemenExpress        7000
# 8  Zemen Express®    @ZemenExpress        6999
# 9  Zemen Express®    @ZemenExpress        6998
#
#                                         Message Text  \
# 0  💥💥...................................💥💥\n\n🎯 L...
# 1  💥💥...................................💥💥\n\n🎯 L...
# 2  💥💥...................................💥💥\n\n🎯 L...
# 3  💥💥👀 ...........💥💥\n\n📌 Electric Charcoal Burne...
# 4                                                NaN
# 5                                                NaN
# 6                                                NaN
# 7  💥💥👀 ...........💥💥\n\n📌 Electric Charcoal Burne...
# 8  💥💥👀 ...........💥💥\n\n📌 Electric Charcoal Burne...
# 9                                                NaN
#
#                         Date  Views Replies  Forwards
# 0  2025-06-24 11:49:18+00:00   1483       0         1
# 1  2025-06-24 11:49:01+00:00   1223       0         2
# 2  2025-06-24 11:48:41+00:00   1246       0         0
# 3  2025-06-23 14:55:46+00:00   2368       0         3
# 4  2025-06-23 14:55:40+00:00   1996       0         0
# 5  2025-06-23 14:55:40+00:00   1988       0         0
# 6  2025-06-23 14:55:40+00:00   1987       0         0
# 7  2025-06-23 14:55:40+00:00   1920       0         0
# 8  2025-06-23 14:55:30+00:00   1949       0         1
# 9  2025-06-23 08:23:14+00:00   2813       0         4

# %%
df_processed = preprocess_dataframe(df, text_col='Message Text')

print(f"Total messages after cleaning: {len(df_processed)}")
df_processed.head(3)
# Out:
# Token indices sequence length is longer than the specified maximum sequence length for this model (843 > 512). Running this sequence through the model will result in indexing errors
# Total messages after cleaning: 14772
#     Channel Title Channel Username  Message ID  \
# 0  Zemen Express®    @ZemenExpress        7007
# 1  Zemen Express®    @ZemenExpress        7006
# 2  Zemen Express®    @ZemenExpress        7005
#
#                                         Message Text  \
# 0  💥💥...................................💥💥\n\n🎯 L...
# 1  💥💥...................................💥💥\n\n🎯 L...
# 2  💥💥...................................💥💥\n\n🎯 L...
#
#                         Date  Views Replies  Forwards  \
# 0  2025-06-24 11:49:18+00:00   1483       0         1
# 1  2025-06-24 11:49:01+00:00   1223       0         2
# 2  2025-06-24 11:48:41+00:00   1246       0         0
#
#                                         cleaned_text  \
# 0  ................................... ልጅዎ 8.5 ልጆ...
# 1  ................................... ልጅዎ 8.5 ልጆ...
# 2  ................................... ልጅዎ 8.5 ልጆ...
#
#                                               tokens
# 0  [▁..., ................, ................, ▁ልጅ...
# 1  [▁..., ................, ................, ▁ልጅ...
# 2  [▁..., ................, ................, ▁ልጅ...

# %%
for i, row in df_processed.sample(5).iterrows():
    print(f"Original Message:\n{row['Message Text']}\n")
    print(f"Cleaned Text:\n{row['cleaned_text']}\n")
    print(f"Tokens:\n{row['tokens']}\n")
    print("-"*60)
# Out:
# Original Message:
# BERR BRAND
# 25-30 ቁጥር
# 1550birr
# 0905707448
# 0945097042
#
# Cleaned Text:
# 2530 ቁጥር 1550 0905707448 0945097042
#
# Tokens:
# ['▁25', '30', '▁ቁጥር', '▁15', '50', '▁09', '05', '707', '448', '▁09', '450', '970', '42']
#
# ------------------------------------------------------------
# Original Message:
# ተገጣጣሚ 4D HUMAN ANATOMY
# ትምህርታዊ መጫዎቻዎች!!
#
# መነሻዬ የልጆችዎን መነሻ የሚያቀሉ ትምህርታዊ መጫዎቻዎችን የሚገኙበት ስፍራ!!
#
# 📍ጉርድ ሾላ ሆሊ ሲቲ ሴንተር 3ኛ ፎቅ
#
# ይደውሉ 0989939393 / 0930323334
# website:- https://meneshaye-official.com/en/meneshaye-4d-anatomy.html
#
# #meneshaye #መነሻዬ #educational #humananatomy #anatomy #anatomydrawing #medicine  #drawing #medical  #anatomystudy #anatomyart #medicalstudent #physiology #artist #anatomynotes #biology #muscles   #humanbody #study #anatomysketch  #illustration #science #anatomypractice  #human
#
# Cleaned Text:
# ተገጣጣሚ 4 ትምህርታዊ መጫዎቻዎች!! መነሻዬ ልጆችዎን መነሻ ሚያቀሉ ትምህርታዊ መጫዎቻዎችን ሚገኙበት ስፍራ!! ጉርድ ሾላ ሆሊ ሲቲ ሴንተር 3ኛ ፎቅ ይደውሉ 0989939393 0930323334 መነሻዬ
#
# Tokens:
# ['▁ተገ', 'ጣጣ', 'ሚ', '▁4', '▁ት', 'ምህር', 'ታዊ', '▁መ', 'ጫ', 'ዎ', 'ቻ', 'ዎች', '!!', '▁መነሻ', 'ዬ', '▁ልጆች', 'ዎን', '▁መነሻ', '▁', 'ሚያ', 'ቀ', 'ሉ', '▁ት', 'ምህር', 'ታዊ', '▁መ', 'ጫ', 'ዎ', 'ቻ', 'ዎችን', '▁ሚ', 'ገኙ', 'በት', '▁ስፍራ', '!!', '▁ጉ', 'ርድ', '▁', 'ሾ', 'ላ', '▁ሆ', 'ሊ', '▁ሲ', 'ቲ', '▁', 'ሴ', 'ን', 'ተር', '▁3', 'ኛ', '▁', 'ፎ', 'ቅ', '▁ይ', 'ደው', 'ሉ', '▁09', '899', '39', '393', '▁09', '30', '3', '23', '334', '▁መነሻ', 'ዬ']
#
# ------------------------------------------------------------
# Original Message:
# የሚገጣጠሙ መጫወቻዎችን በተለያዩ አማራጮች የሚሸምቱበት ምርጥ ስፍራ
#
#
# አድራሻ፦
# 📍ጉርድ ሾላ ሆሊ ሲቲ ሴንተር 3ኛ ፎቅ
# ይምጡ በመነሻዬ የልጅዎን መነሻ ያቅልሉ!
#
# ይደውሉ 0989939393 ወይም 0930323334
#
# Telegram > http://t.me/meneshayeofficial
# Tiktok > http://tiktok.com/@meneshayeofficial
# Facebook > http://facebook.com/@meneshayeofficial
#
# #creativity #imagination #concentration #gift   #entertain #toy #kid #daycare #store #educationaltoys #meneshaye
# #meneshayestore
#
# Cleaned Text:
# ሚገጣጠሙ መጫወቻዎችን ተለያዩ አማራጮች ሚሸምቱበት ምርጥ ስፍራ አድራሻ፦ ጉርድ ሾላ ሆሊ ሲቲ ሴንተር 3ኛ ፎቅ ይምጡ መነሻዬ ልጅዎን መነሻ ያቅልሉ! ይደውሉ 0989939393 ወይም 0930323334
#
# Tokens:
# ['▁ሚ', 'ገ', 'ጣ', 'ጠ', 'ሙ', '▁መ', 'ጫ', 'ወ', 'ቻ', 'ዎችን', '▁', 'ተለያዩ', '▁አማራ', 'ጮ', 'ች', '▁ሚ', 'ሸ', 'ም', 'ቱ', 'በት', '▁ምርጥ', '▁ስፍራ', '▁አድራሻ', '፦', '▁ጉ', 'ርድ', '▁', 'ሾ', 'ላ', '▁ሆ', 'ሊ', '▁ሲ', 'ቲ', '▁', 'ሴ', 'ን', 'ተር', '▁3', 'ኛ', '▁', 'ፎ', 'ቅ', '▁ይ', 'ም', 'ጡ', '▁መነሻ', 'ዬ', '▁ልጅ', 'ዎን', '▁መነሻ', '▁ያ', 'ቅል', 'ሉ', '!', '▁ይ', 'ደው', 'ሉ', '▁09', '899', '39', '393', '▁ወይም', '▁09', '30', '3', '23', '334']
#
# ------------------------------------------------------------
# Original Message:
# ተወዳጇ ድምጻዊት ቤቲ ጂ መነሻዬን ወድዋለች....እናመሰግናለን
#
# ለበለጠ 👉https://meneshaye-official.com/meneshaye-lelije/
#
# Cleaned Text:
# ተወዳጇ ድምጻዊት ቤቲ ጂ መነሻዬን ወድዋለች....እናመሰግናለን በለጠ
#
# Tokens:
# ['▁ተ', 'ወ', 'ዳ', 'ጇ', '▁ድም', 'ጻ', 'ዊ', 'ት', '▁', 'ቤ', 'ቲ', '▁', 'ጂ', '▁መነሻ', 'ዬ', 'ን', '▁', 'ወድ', 'ዋ', 'ለች', '.', '...', 'እ', 'ና', 'መሰ', 'ግ', 'ና', 'ለን', '▁በ', 'ለጠ']
#
# ------------------------------------------------------------
# Original Message:
# 💥💥...................................💥💥
#
# 📌Door Bottom Seal Strip Stopper
# 👍በበርዎ ስር አቧራ እና ነፍሳት እንዳይገባ
#     የሚከላከል!!!
# 💯 High Quality
# ®️ አንደኛው ወፍራሙ
#
# 🔰Keep Hot and Cold Air isolated
# 🔰 Reduce The Noise Outside and Door slamming
# 🔰 No 🦟 🪰 🐀 🪳🕷️🐛🦗
#
#
#  ዋጋ፦  💰🏷  400ብር
#
# ♦️ውስን ፍሬ ነው ያለው 🔥🔥🔥
#
# 🏢 አድራሻ👉
# 📍ቁ.1️⃣♦️መገናኛ መሰረት ደፋር ሞል ሁለተኛ ፎቅ ቢሮ ቁ. S05/S06
#
# 📍 ቁ.2️⃣♦️ፒያሳ ጊዮርጊስ አደባባይ ራመት_ታቦር_ኦዳ_ህንፃ 1ኛ ፎቅ ሱቅ ቁ. G1 -107
#
#
#
#      💧💧💧💧
#
#
#     📲 0902660722
#     📲 0928460606
#
# 🔖
# 💬በTelegram ለማዘዝ ⤵️ ይጠቀሙ🔽
#
# @zemencallcenter
#
# @zemenexpressadmin
#
# ለተጨማሪ ማብራሪያ የቴሌግራም ገፃችን⤵️
# https://telegram.me/zemenexpress
#
# 💥💥...................................💥💥
#
# Cleaned Text:
# ................................... በርዎ ስር አቧራ እና ነፍሳት እንዳይገባ ሚከላከል!!! አንደኛው ወፍራሙ ዋጋ፦ 400ብር ውስን ፍሬ ነው ያለው አድራሻ ቁ.1መገናኛ መሰረት ደፋር ሞል ሁለተኛ ፎቅ ቢሮ ቁ. 0506 ቁ.2ፒያሳ ጊዮርጊስ አደባባይ ራመትታቦርኦዳህንፃ 1ኛ ፎቅ ሱቅ ቁ. 1 107 0902660722 0928460606 በ ማዘዝ ይጠቀሙ ተጨማሪ ማብራሪያ ቴሌግራም ገፃችን ...................................
#
# Tokens:
# ['▁...', '................', '................', '▁በር', 'ዎ', '▁ስር', '▁አ', 'ቧ', 'ራ', '▁እና', '▁', 'ነፍ', 'ሳት', '▁እንዳይ', 'ገባ', '▁ሚ', 'ከላከ', 'ል', '!!!', '▁አንደ', 'ኛው', '▁ወ', 'ፍራ', 'ሙ', '▁ዋጋ', '፦', '▁400', 'ብር', '▁', 'ውስ', 'ን', '▁ፍ', 'ሬ', '▁ነው', '▁ያለው', '▁አድራሻ', '▁ቁ', '.', '1', 'መ', 'ገና', 'ኛ', '▁መሰረት', '▁ደ', 'ፋር', '▁ሞ', 'ል', '▁', 'ሁለተኛ', '▁', 'ፎ', 'ቅ', '▁ቢሮ', '▁ቁ', '.', '▁05', '06', '▁ቁ', '.', '2', 'ፒ', 'ያ', 'ሳ', '▁', 'ጊዮርጊስ', '▁አደባባይ', '▁', 'ራ', 'መት', 'ታ', 'ቦ', 'ር', 'ኦ', 'ዳ', 'ህን', 'ፃ', '▁1', 'ኛ', '▁', 'ፎ', 'ቅ', '▁', 'ሱ', 'ቅ', '▁ቁ', '.', '▁1', '▁107', '▁09', '02', '660', '722', '▁09', '28', '460', '606', '▁በ', '▁ማ', 'ዘ', 'ዝ', '▁ይ', 'ጠቀሙ', '▁ተጨማሪ', '▁ማብራሪያ', '▁', 'ቴ', 'ሌ', 'ግራ', 'ም', '▁ገ', 'ፃ', 'ችን', '▁...', '................', '................']
#
# ------------------------------------------------------------

# %%
output_path = Path('../data/processed/cleaned_messages.csv')
output_path.parent.mkdir(parents=True, exist_ok=True)

df_processed.to_csv(output_path, index=False, encoding='utf-8-sig')
print(f"[✅] Saved cleaned and tokenized data to {output_path}")
# Out:
# [✅] Saved cleaned and tokenized data to ..\data\processed\cleaned_messages.csv
