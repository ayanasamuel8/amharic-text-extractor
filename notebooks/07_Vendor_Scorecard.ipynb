# %%
import sys
sys.path.append('../scripts')

# %%
import pandas as pd
from ner_utils import load_ner_pipeline, enrich_dataframe_with_entities

# Load NER pipeline
model_path = "../data/processed/fine_tunned_XLM-Roberta"
ner_pipeline = load_ner_pipeline(model_path)

# Load your data
df = pd.read_csv("../data/processed/cleaned_messages.csv")

# Enrich DataFrame
df = enrich_dataframe_with_entities(df, text_col="cleaned_text", ner_pipeline=ner_pipeline)

# Save for next step
df.to_csv("../outputs/enriched_data.csv", index=False)
df.head()
# Out:
# Device set to use cpu
# c:\Users\user\OneDrive\Documents\Data Science\amharic-text-extractor\EthioMart-NER-Project\.venv\Lib\site-packages\transformers\pipelines\token_classification.py:170: UserWarning: `grouped_entities` is deprecated and will be removed in version v5.0.0, defaulted to `aggregation_strategy="AggregationStrategy.SIMPLE"` instead.
#   warnings.warn(
#     Channel Title Channel Username  Message ID  \
# 0  Zemen Express®    @ZemenExpress        7007
# 1  Zemen Express®    @ZemenExpress        7006
# 2  Zemen Express®    @ZemenExpress        7005
# 3  Zemen Express®    @ZemenExpress        7004
# 4  Zemen Express®    @ZemenExpress        7000
#
#                                         Message Text  \
# 0  💥💥...................................💥💥\n\n🎯 L...
# 1  💥💥...................................💥💥\n\n🎯 L...
# 2  💥💥...................................💥💥\n\n🎯 L...
# 3  💥💥👀 ...........💥💥\n\n📌 Electric Charcoal Burne...
# 4  💥💥👀 ...........💥💥\n\n📌 Electric Charcoal Burne...
#
#                         Date  Views Replies  Forwards  \
# 0  2025-06-24 11:49:18+00:00   1483       0         1
# 1  2025-06-24 11:49:01+00:00   1223       0         2
# 2  2025-06-24 11:48:41+00:00   1246       0         0
# 3  2025-06-23 14:55:46+00:00   2368       0         3
# 4  2025-06-23 14:55:40+00:00   1920       0         0
#
#                                         cleaned_text  \
# 0  ................................... ልጅዎ 8.5 ልጆ...
# 1  ................................... ልጅዎ 8.5 ልጆ...
# 2  ................................... ልጅዎ 8.5 ልጆ...
# 3  ........... ቀላሉ ሰል ማያያዝ ሚሆን አነስ ያለ ቦታ ማይዝ ኤሌክት...
# 4  ........... ቀላሉ ሰል ማያያዝ ሚሆን አነስ ያለ ቦታ ማይዝ ኤሌክት...
#
#                                               tokens       extracted_prices  \
# 0  ['▁...', '................', '...................  8.5, ብርሀን, ዋጋ፦ 550 ብር
# 1  ['▁...', '................', '...................  8.5, ብርሀን, ዋጋ፦ 550 ብር
# 2  ['▁...', '................', '...................  8.5, ብርሀን, ዋጋ፦ 550 ብር
# 3  ['▁', '...........', '▁ቀ', 'ላ', 'ሉ', '▁', 'ሰል'...            ዋጋ፦ 1600 ብር
# 4  ['▁', '...........', '▁ቀ', 'ላ', 'ሉ', '▁', 'ሰል'...            ዋጋ፦ 1600 ብር
#
#                         extracted_products
# 0  ..., ................, ................
# 1  ..., ................, ................
# 2  ..., ................, ................
# 3                            , ...........
# 4                            , ...........

# %%
df.tail()
# Out:
#            Channel Title Channel Username  Message ID  \
# 14767  SINA KIDS/ሲና ኪድስⓇ        @sinayelj         674
# 14768  SINA KIDS/ሲና ኪድስⓇ        @sinayelj         640
# 14769  SINA KIDS/ሲና ኪድስⓇ        @sinayelj         605
# 14770  SINA KIDS/ሲና ኪድስⓇ        @sinayelj         598
# 14771  SINA KIDS/ሲና ኪድስⓇ        @sinayelj         182
#
#                                             Message Text  \
# 14767  ምቹ የልጆች ፖፖ የሶፍት ማስቀመጫ ያለው 1000ብር\nFree deliver...
# 14768  ለልጆች ምቹ እና ኮንፈርተብል ማት \nከላይ ማጫወቻ ያለዉ ከተፈለገ ማጫወ...
# 14769  Baby potty \nበባትሪ የሚሰራ ድምፅ ያለው\nየልጆች ፖፖ 899 ብር...
# 14770                 Baby potty\n0905707448\n0945097042
# 14771  ውድ የሲና ኪድስ ደምበኞች በድጋሚ ገብቷል \nየመዋኛ ገንዳ ትልቅ ሳይዝ ...
#
#                             Date  Views Replies  Forwards  \
# 14767  2021-04-28 19:12:19+00:00  24385       0        28
# 14768  2021-04-20 11:16:59+00:00  23692       0        19
# 14769  2021-04-16 18:27:22+00:00  23798       0        42
# 14770  2021-04-16 18:12:10+00:00  21610       0        10
# 14771  2020-11-10 06:59:31+00:00  26845       0        34
#
#                                             cleaned_text  \
# 14767  ምቹ ልጆች ፖፖ ሶፍት ማስቀመጫ ያለው 1000ብር 0905707448 0945...
# 14768  ልጆች ምቹ እና ኮንፈርተብል ማት ላይ ማጫወቻ ያለዉ ተፈለገ ማጫወቻዉን አ...
# 14769  ባትሪ ሚሰራ ድምፅ ያለው ልጆች ፖፖ 899 ብር 0905707448 09450...
# 14770                              0905707448 0945097042
# 14771  ውድ ሲና ኪድስ ደምበኞች ድጋሚ ገብቷል መዋኛ ገንዳ ትልቅ ሳይዝ ራሱ መን...
#
#                                                   tokens extracted_prices  \
# 14767  ['▁ም', 'ቹ', '▁ልጆች', '▁ፖ', 'ፖ', '▁', 'ሶ', 'ፍት',...           1000ብር
# 14768  ['▁ልጆች', '▁ም', 'ቹ', '▁እና', '▁ኮን', 'ፈር', 'ተ', '...          2500 ብር
# 14769  ['▁', 'ባት', 'ሪ', '▁ሚ', 'ሰራ', '▁ድምፅ', '▁ያለው', '...           899 ብር
# 14770  ['▁09', '05', '707', '448', '▁09', '450', '970...             None
# 14771  ['▁ውድ', '▁ሲ', 'ና', '▁ኪ', 'ድስ', '▁', 'ደም', 'በ',...             None
#
#                extracted_products
# 14767   ም, ቹ ልጆች ፖፖ ሶፍት ማስቀመጫ ያለው
# 14768           ልጆች ምቹ እና ኮንፈርተብል
# 14769  , ባት, ሪ ሚሰራ ድምፅ ያለው ልጆች ፖፖ
# 14770            09, 05, 707, 448
# 14771    ውድ ሲና ኪድስ ደምበኞች ድጋሚ ገብቷል
